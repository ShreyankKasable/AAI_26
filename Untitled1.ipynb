# %%
import labelme
import tensorflow as tf

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalMaxPooling2D
from tensorflow.keras.applications import VGG16

# %%
import os
import uuid
import cv2

# %%
image_path = os.path.join('data', 'images')
number_images = 30

# %%
cap = cv2.VideoCapture(0)

for imgnum in range(number_images):
    print("Collecting image {}".format(imgnum))
    ret, frame = cap.read()
    imgname = os.path.join(image_path, f'{str(uuid.uuid1())}.jpg')
    cv2.imwrite(imgname, frame)
    cv2.imshow("FRAME", frame)
    time.sleep(0.5)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### ANNOTATING IMAGES WITH LABELME

# %%
# !labelme
# Out:
# 2025-01-27 11:44:08,616 [INFO   ] __init__:get_config:67- Loading config file from: C:\Users\shrey\.labelmerc

# %% [markdown]
# ### REVIEW DATASET AND BUILD LOADING FUNCTION

# %% [markdown]
# #### IMPORT REQUIRE LIBRARIES

# %%
import tensorflow as tf
import cv2
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
print("TENSORFLOW",tf.__version__)
print("CV2",cv2.__version__)
print("JSON",json.__version__)
print("NUMPY",np.__version__)
# Out:
# TENSORFLOW 2.18.0
# CV2 4.11.0
# JSON 2.0.9
# NUMPY 1.24.3

# %% [markdown]
# #### Load Images into TF Data Pipeline

# %%
images = tf.data.Dataset.list_files("data/images/*.jpg", shuffle=False)

# %%
import os

files = os.listdir("data/images/")
print("First 10 files:", files[:10])  # Display the first 10 files
# Out:
# First 10 files: ['4328a069-dcc9-11ef-b0d4-e290d3988284.jpg']

# %%
images.as_numpy_iterator().next()
# Out:
# b'data\\images\\9fecff47-8e26-11ef-b8d4-bfb07c1744f6.jpg'

# %%
def load_image(x):
    
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

# %%
images = images.map(load_image)

# %%
images.as_numpy_iterator().next()
# Out:
# array([[[189, 182, 163],
#         [189, 182, 163],
#         [190, 182, 161],
#         ...,
#         [136, 151, 132],
#         [136, 151, 132],
#         [132, 147, 128]],
#
#        [[189, 182, 163],
#         [189, 182, 163],
#         [190, 183, 164],
#         ...,
#         [136, 150, 133],
#         [132, 146, 129],
#         [127, 142, 123]],
#
#        [[188, 183, 164],
#         [188, 183, 163],
#         [189, 184, 164],
#         ...,
#         [137, 151, 136],
#         [133, 147, 132],
#         [130, 144, 127]],
#
#        ...,
#
#        [[148, 122,  65],
#         [148, 122,  65],
#         [148, 122,  63],
#         ...,
#         [ 19,  20,  48],
#         [ 19,  19,  45],
#         [ 19,  19,  45]],
#
#        [[148, 121,  66],
#         [147, 121,  64],
#         [147, 123,  63],
#         ...,
#         [ 16,  20,  47],
#         [ 18,  20,  45],
#         [ 18,  20,  45]],
#
#        [[150, 123,  68],
#         [149, 123,  66],
#         [148, 124,  64],
#         ...,
#         [ 14,  18,  45],
#         [ 16,  18,  43],
#         [ 16,  18,  43]]], dtype=uint8)

# %%
type(images)
# Out:
# tensorflow.python.data.ops.map_op._MapDataset

# %%
images_generator = images.batch(4).as_numpy_iterator()

# %%
plot_images = images_generator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20, 20))
for idx, image in enumerate(plot_images):
    ax[idx].imshow(image)
plt.show()

# %% [markdown]
# ### PARTITION UNAUGMENTED DATA

# %% [markdown]
# #### moving the matching labels

# %%
for folder in ['train', 'test', 'val']:
    for file in os.listdir(os.path.join('data', folder, 'images')):
        
        filename = file.split('.')[0]+'.json'
        existing_filepath = os.path.join('data', 'labels', filename)
        
        if os.path.exists(existing_filepath):
            
            new_filepath = os.path.join('data', folder, 'labels', filename)
            os.replace(existing_filepath, new_filepath)

# %% [markdown]
# ### Applying image augmentation on images and labels using albumentations

# %%
import albumentations as alb

# %%
img = cv2.imread(os.path.join('data', 'train', 'images', '9fecff47-8e26-11ef-b8d4-bfb07c1744f6.jpg'))

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
augmentor = alb.Compose([alb.RandomCrop(width=450, height=450),
                         alb.HorizontalFlip(p=0.5),
                         alb.RandomBrightnessContrast(p=0.2),
                         alb.RandomGamma(p=0.2),
                         alb.RGBShift(p=0.2),
                         alb.VerticalFlip(p=0.5)],
                        bbox_params=alb.BboxParams(format='albumentations',
                                                  label_fields=['class_labels']))

# %%
with open(os.path.join('data', 'train', 'labels', 'a096edfd-8e26-11ef-9e65-bfb07c1744f6.json'), 'r') as f:
    label = json.load(f)

# %%
label['shapes'][0]['points']
# Out:
# [[280.4651162790698, 65.29069767441861],
#  [506.62790697674416, 340.8720930232558]]

# %% [markdown]
# #### 4.3 Extract Co-ordinates and Rescale to match images Resolution

# %%
coords = [0, 0, 0, 0]
coords[0] = label['shapes'][0]['points'][0][0]
coords[1] = label['shapes'][0]['points'][0][1]
coords[2] = label['shapes'][0]['points'][1][0]
coords[3] = label['shapes'][0]['points'][1][1]

# %%
coords
# Out:
# [280.4651162790698, 65.29069767441861, 506.62790697674416, 340.8720930232558]

# %%
coords = list(np.divide(coords, [640, 480, 640, 480]))

# %%
coords
# Out:
# [0.4382267441860465,
#  0.13602228682170545,
#  0.7916061046511628,
#  0.7101501937984496]

# %%
#### Applying Augmentations and viewing Results

# %%
augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])

# %%
augmented['image'].shape
# Out:
# (450, 450, 3)

# %%
augmented['bboxes']
# Out:
# [[0.5143669043646918, 0.30250647226969396, 1.0, 0.9149095630645752]]

# %%
cv2.rectangle(augmented['image'],
             tuple(np.multiply(augmented['bboxes'][0][:2], [450, 450]).astype(int)),
             tuple(np.multiply(augmented['bboxes'][0][2:], [450, 450]).astype(int)),
             (255, 0, 0), 2)
plt.imshow(augmented['image'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 cv2.rectangle(augmented['image'],
#       2              tuple(np.multiply(augmented['bboxes'][0][:2], [450, 450]).astype(int)),
#       3              tuple(np.multiply(augmented['bboxes'][0][2:], [450, 450]).astype(int)),
#       4              (255, 0, 0), 2)
#       5 plt.imshow(augmented['image'])
#
# NameError: name 'augmented' is not defined

# %% [markdown]
# ### Run Augmentation Pipeline

# %%
for partition in ['train','test','val']: 
    for image in os.listdir(os.path.join('data', partition, 'images')):
        img = cv2.imread(os.path.join('data', partition, 'images', image))

        coords = [0,0,0.00001,0.00001]
        label_path = os.path.join('data', partition, 'labels', f'{image.split(".")[0]}.json')
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)

            coords[0] = label['shapes'][0]['points'][0][0]
            coords[1] = label['shapes'][0]['points'][0][1]
            coords[2] = label['shapes'][0]['points'][1][0]
            coords[3] = label['shapes'][0]['points'][1][1]
            coords = list(np.divide(coords, [640,480,640,480]))

        try: 
            for x in range(60):
                augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
                cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(".")[0]}.{x}.jpg'), augmented['image'])

                annotation = {}
                annotation['image'] = image

                if os.path.exists(label_path):
                    if len(augmented['bboxes']) == 0: 
                        annotation['bbox'] = [0,0,0,0]
                        annotation['class'] = 0 
                    else: 
                        annotation['bbox'] = augmented['bboxes'][0]
                        annotation['class'] = 1
                else: 
                    annotation['bbox'] = [0,0,0,0]
                    annotation['class'] = 0 


                with open(os.path.join('aug_data', partition, 'labels', f'{image.split(".")[0]}.{x}.json'), 'w') as f:
                    json.dump(annotation, f)

        except Exception as e:
            print(e)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[123], line 19
#      17 try:
#      18     for x in range(60):
# ---> 19         augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
#      20         cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(".")[0]}.{x}.jpg'), augmented['image'])
#      22         annotation = {}
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\core\composition.py:446, in Compose.__call__(self, force_apply, *args, **data)
#     443     self._track_transform_params(t, data)
#     444     data = self.check_data_post_transform(data)
# --> 446 return self.postprocess(data)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\core\composition.py:510, in Compose.postprocess(self, data)
#     508 if self.main_compose:
#     509     for p in self.processors.values():
# --> 510         p.postprocess(data)
#     512     # Convert back to list if original input was a list
#     513     if "images" in data and self._images_was_list:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\core\utils.py:170, in DataProcessor.postprocess(self, data)
#     168 def postprocess(self, data: dict[str, Any]) -> dict[str, Any]:
#     169     shape = get_shape(data)
# --> 170     data = self._process_data_fields(data, shape)
#     171     data = self.remove_label_fields_from_data(data)
#     172     return self._convert_sequence_inputs(data)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\core\utils.py:176, in DataProcessor._process_data_fields(self, data, shape)
#     174 def _process_data_fields(self, data: dict[str, Any], shape: ShapeType) -> dict[str, Any]:
#     175     for data_name in set(self.data_fields) & set(data.keys()):
# --> 176         data[data_name] = self._process_single_field(data_name, data[data_name], shape)
#     177     return data
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\core\utils.py:180, in DataProcessor._process_single_field(self, data_name, field_data, shape)
#     179 def _process_single_field(self, data_name: str, field_data: Any, shape: ShapeType) -> Any:
# --> 180     field_data = self.filter(field_data, shape)
#     182     if data_name == "keypoints" and len(field_data) == 0:
#     183         field_data = self._create_empty_keypoints_array()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\core\bbox_utils.py:219, in BboxProcessor.filter(self, data, shape)
#     217 def filter(self, data: np.ndarray, shape: ShapeType) -> np.ndarray:
#     218     self.params: BboxParams
# --> 219     return filter_bboxes(
#     220         data,
#     221         shape,
#     222         min_area=self.params.min_area,
#     223         min_visibility=self.params.min_visibility,
#     224         min_width=self.params.min_width,
#     225         min_height=self.params.min_height,
#     226     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\core\bbox_utils.py:625, in filter_bboxes(bboxes, shape, min_area, min_visibility, min_width, min_height)
#     622 denormalized_box_areas = calculate_bbox_areas_in_pixels(bboxes, shape)
#     624 # Clip bounding boxes in ratio
# --> 625 clipped_bboxes = clip_bboxes(bboxes, shape)
#     627 # Calculate areas of clipped bounding boxes in pixels
#     628 clipped_box_areas = calculate_bbox_areas_in_pixels(clipped_bboxes, shape)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\augmentations\utils.py:189, in handle_empty_array.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 if len(array) == 0:
#     188     return array
# --> 189 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\core\bbox_utils.py:587, in clip_bboxes(bboxes, shape)
#     584 denorm_bboxes[:, [1, 3]] = np.clip(denorm_bboxes[:, [1, 3]], 0, height, out=denorm_bboxes[:, [1, 3]])
#     586 # Normalize clipped bboxes
# --> 587 return normalize_bboxes(denorm_bboxes, shape)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\augmentations\utils.py:189, in handle_empty_array.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 if len(array) == 0:
#     188     return array
# --> 189 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\albumentations\core\bbox_utils.py:330, in normalize_bboxes(bboxes, shape)
#     327     rows, cols = shape["height"], shape["width"]
#     329 normalized = bboxes.copy().astype(float)
# --> 330 normalized[:, [0, 2]] /= cols
#     331 normalized[:, [1, 3]] /= rows
#     332 return normalized
#
# KeyboardInterrupt:

# %% [markdown]
# #### load Augmented Images to Tensorflow Dataset

# %%
train_images = tf.data.Dataset.list_files('aug_data\\train\\images\\*.jpg', shuffle=False)
train_images = train_images.map(load_image)
train_images = train_images.map(lambda x: tf.image.resize(x, (120,120)))
train_images = train_images.map(lambda x: x/255)

# %%
test_images = tf.data.Dataset.list_files('aug_data\\test\\images\\*.jpg', shuffle=False)
test_images = test_images.map(load_image)
test_images = test_images.map(lambda x: tf.image.resize(x, (120,120)))
test_images = test_images.map(lambda x: x/255)

# %%
val_images = tf.data.Dataset.list_files('aug_data\\val\\images\\*.jpg', shuffle=False)
val_images = val_images.map(load_image)
val_images = val_images.map(lambda x: tf.image.resize(x, (120,120)))
val_images = val_images.map(lambda x: x/255)

# %%
train_images.as_numpy_iterator().next()
# Out:
# array([[[0.04460784, 0.12303922, 0.31911764],
#         [0.03363971, 0.11243872, 0.30833334],
#         [0.02824755, 0.11452206, 0.30667892],
#         ...,
#         [0.62579656, 0.54129905, 0.37659314],
#         [0.6415441 , 0.5509804 , 0.36881128],
#         [0.6234069 , 0.5401348 , 0.33504903]],
#
#        [[0.03480392, 0.11519608, 0.30594364],
#         [0.03878677, 0.12205882, 0.30637255],
#         [0.03627451, 0.12254902, 0.30686274],
#         ...,
#         [0.6394608 , 0.55710787, 0.3865196 ],
#         [0.64754903, 0.56219363, 0.37873775],
#         [0.6235907 , 0.54221815, 0.3476103 ]],
#
#        [[0.05459559, 0.1408701 , 0.3251838 ],
#         [0.05196078, 0.1377451 , 0.32205883],
#         [0.05055147, 0.13290441, 0.31721812],
#         ...,
#         [0.64215684, 0.5602941 , 0.3745098 ],
#         [0.64509803, 0.55588233, 0.38186276],
#         [0.61813724, 0.53186274, 0.3401348 ]],
#
#        ...,
#
#        [[0.6954044 , 0.64981616, 0.56354165],
#         [0.68713236, 0.6557598 , 0.5665441 ],
#         [0.6887255 , 0.66519606, 0.57892156],
#         ...,
#         [0.72794116, 0.70441175, 0.60245097],
#         [0.72751224, 0.7108456 , 0.60545343],
#         [0.7135417 , 0.6978554 , 0.59197307]],
#
#        [[0.6831495 , 0.64001226, 0.5615809 ],
#         [0.6901961 , 0.6598039 , 0.5769608 ],
#         [0.6759191 , 0.6558211 , 0.57640934],
#         ...,
#         [0.7245098 , 0.7078431 , 0.60245097],
#         [0.7210172 , 0.7053309 , 0.60631126],
#         [0.7137255 , 0.7006127 , 0.5982843 ]],
#
#        [[0.67726713, 0.6341299 , 0.5606005 ],
#         [0.68645835, 0.64773285, 0.56844366],
#         [0.6865809 , 0.66139704, 0.5856005 ],
#         ...,
#         [0.7188113 , 0.703125  , 0.6050858 ],
#         [0.72585785, 0.7127451 , 0.61470586],
#         [0.715625  , 0.70104164, 0.6011642 ]]], dtype=float32)

# %% [markdown]
# ### 6. PREPARE LABEL

# %% [markdown]
# #### Building label loading function

# %%
def load_labels(label_path):
    with open(label_path.numpy(), 'r', encoding = "utf-8") as f:
        label = json.load(f)
        
    return [label['class']], label['bbox']

# %% [markdown]
# #### Load Labels to TensorFlow Dataset

# %%
train_labels = tf.data.Dataset.list_files('aug_data\\train\\labels\\*.json', shuffle=False)
train_labels = train_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
test_labels = tf.data.Dataset.list_files('aug_data\\test\\labels\\*.json', shuffle=False)
test_labels = test_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
val_labels = tf.data.Dataset.list_files('aug_data\\val\\labels\\*.json', shuffle=False)
val_labels = val_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
train_labels.as_numpy_iterator().next()
# Out:
# (array([1], dtype=uint8),
#  array([0.    , 0.2393, 0.4338, 0.906 ], dtype=float16))

# %% [markdown]
# ### Combining Label and Image Samples

# %%
len(train_images), len(train_labels), len(test_images), len(test_labels), len(val_images), len(val_labels)
# Out:
# (3780, 3780, 840, 840, 780, 780)

# %% [markdown]
# ### Create Final Datasets

# %%
train = tf.data.Dataset.zip((train_images, train_labels))
train = train.shuffle(5000)
train = train.batch(8)
train = train.prefetch(4)

# %%
test = tf.data.Dataset.zip((test_images, test_labels))
test = test.shuffle(1300)
test = test.batch(8)
test = test.prefetch(4)

# %%
val = tf.data.Dataset.zip((val_images, val_labels))
val = val.shuffle(1000)
val = val.batch(8)
val = val.prefetch(4)

# %%
train.as_numpy_iterator().next()[1]
# Out:
# (array([[1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1]], dtype=uint8),
#  array([[0.3455 , 0.1729 , 0.845  , 0.719  ],
#         [0.5137 , 0.2345 , 0.9204 , 0.7446 ],
#         [0.139  , 0.00535, 0.6235 , 0.614  ],
#         [0.3257 , 0.317  , 0.694  , 0.773  ],
#         [0.01607, 0.509  , 0.5483 , 1.     ],
#         [0.1742 , 0.3284 , 0.594  , 0.778  ],
#         [0.     , 0.2659 , 0.3025 , 0.7607 ],
#         [0.4873 , 0.1791 , 0.974  , 0.6855 ]], dtype=float16))

# %%
data_samples = train.as_numpy_iterator()

# %%
res = data_samples.next()

# %%
data_samples = train.as_numpy_iterator()
res = data_samples.next()

fig, ax = plt.subplots(ncols=4, figsize=(20, 20))
for idx in range(4): 
    sample_image = res[0][idx]
    sample_coords = res[1][1][idx]
    
    sample_image = sample_image.copy()
    
    cv2.rectangle(
        sample_image, 
        tuple(np.multiply(sample_coords[:2], [120, 120]).astype(int)),
        tuple(np.multiply(sample_coords[2:], [120, 120]).astype(int)), 
        (255, 0, 0), 2
    )
    ax[idx].imshow(sample_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].

# %% [markdown]
# ### BUILDING DEEP LEARNING USING THE FUNCTIONAL API

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalMaxPooling2D
from tensorflow.keras.applications import VGG16

# %%
vgg = VGG16(include_top=False)

# %%
vgg.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, None, None, 64)      │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, None, None, 64)      │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, None, None, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, None, None, 128)     │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, None, None, 128)     │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, None, None, 128)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, None, None, 256)     │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, None, None, 256)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, None, None, 512)     │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def build_model(): 
    # Input Layer
    input_layer = Input(shape=(120, 120, 3))
    
    # VGG16 Backbone
    vgg = VGG16(include_top=False, weights='imagenet')(input_layer)

    # Classification Head
    f1 = GlobalMaxPooling2D()(vgg)
    class1 = Dense(2048, activation='relu')(f1)
    class2 = Dense(1, activation='sigmoid')(class1)  # Binary classification
    
    # Bounding Box Regression Head
    f2 = GlobalMaxPooling2D()(vgg)
    regress1 = Dense(2048, activation='relu')(f2)
    regress2 = Dense(4, activation='sigmoid')(regress1)  # Normalized bounding boxes
    
    # Define Model
    facetracker = Model(inputs=input_layer, outputs=[class2, regress2])
    return facetracker

# %%
facetracker = build_model()

# %%
facetracker.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 120, 120, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ vgg16 (Functional)            │ (None, 3, 3, 512)         │      14,714,688 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling2d          │ (None, 512)               │               0 │ vgg16[0][0]                │
# │ (GlobalMaxPooling2D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling2d_1        │ (None, 512)               │               0 │ vgg16[0][0]                │
# │ (GlobalMaxPooling2D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 2048)              │       1,050,624 │ global_max_pooling2d[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 2048)              │       1,050,624 │ global_max_pooling2d_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 1)                 │           2,049 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 4)                 │           8,196 │ dense_2[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 16,826,181 (64.19 MB)
#  Trainable params: 16,826,181 (64.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X, y = train.as_numpy_iterator().next()

# %%
X.shape
# Out:
# (8, 120, 120, 3)

# %%
classes, coords = facetracker.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
classes, coords
# Out:
# (array([[0.71323025],
#         [0.6379151 ],
#         [0.6712413 ],
#         [0.6796261 ],
#         [0.6950598 ],
#         [0.67851543],
#         [0.7503326 ],
#         [0.66664267]], dtype=float32),
#  array([[0.42100513, 0.6245446 , 0.35538387, 0.61523616],
#         [0.31324822, 0.625185  , 0.30737802, 0.5655232 ],
#         [0.3339724 , 0.759181  , 0.32894778, 0.62333727],
#         [0.4412882 , 0.578382  , 0.29366484, 0.6516049 ],
#         [0.2852269 , 0.61491096, 0.3289826 , 0.5793274 ],
#         [0.32375973, 0.6394069 , 0.44290867, 0.57986057],
#         [0.45570228, 0.7271973 , 0.38630703, 0.6046083 ],
#         [0.33557022, 0.6431813 , 0.39635628, 0.5815633 ]], dtype=float32))

# %%
batches_per_epoch = len(train)
lr_decay = (1./0.75 -1)/batches_per_epoch

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001, decay=lr_decay)
# Out:
# C:\Python311\Lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
def localization_loss(y_true, yhat):            
    delta_coord = tf.reduce_sum(tf.square(y_true[:,:2] - yhat[:,:2]))
                  
    h_true = y_true[:,3] - y_true[:,1] 
    w_true = y_true[:,2] - y_true[:,0] 

    h_pred = yhat[:,3] - yhat[:,1] 
    w_pred = yhat[:,2] - yhat[:,0] 
    
    delta_size = tf.reduce_sum(tf.square(w_true - w_pred) + tf.square(h_true-h_pred))
    
    return delta_coord + delta_size

# %%
classloss = tf.keras.losses.BinaryCrossentropy()
regressloss = localization_loss

# %%
localization_loss(y[1], coords)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=6.051505088806152>

# %%
classloss(y[0], classes)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.37708568572998047>

# %%
class FaceTracker(Model): 
    def __init__(self, eyetracker,  **kwargs): 
        super().__init__(**kwargs)
        self.model = eyetracker

    def compile(self, opt, classloss, localizationloss, **kwargs):
        super().compile(**kwargs)
        self.closs = classloss
        self.lloss = localizationloss
        self.opt = opt
    
    def train_step(self, batch, **kwargs): 
        
        X, y = batch
        
        y[0].set_shape([None, 1])
        
        with tf.GradientTape() as tape: 
            classes, coords = self.model(X, training=True)
            
            batch_classloss = self.closs(y[0], classes)
            batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
            
            total_loss = batch_localizationloss+0.5*batch_classloss
            
            grad = tape.gradient(total_loss, self.model.trainable_variables)
            self.opt.apply_gradients(zip(grad, self.model.trainable_variables))
        
        #opt.apply_gradients(zip(grad, self.model.trainable_variables))
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
    
    def test_step(self, batch, **kwargs): 
        X, y = batch
        
        y[0].set_shape([None, 1])
        
        classes, coords = self.model(X, training=False)
        
        batch_classloss = self.closs(y[0], classes)
        batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
        total_loss = batch_localizationloss+0.5*batch_classloss
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
        
    def call(self, X, **kwargs): 
        return self.model(X, **kwargs)

# %%
model = FaceTracker(facetracker)

# %%
model.compile(opt, classloss, regressloss)

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 584s 1s/step - class_loss: 0.0406 - regress_loss: 0.1779 - total_loss: 0.1982 - val_class_loss: 9.6832e-05 - val_regress_loss: 0.0361 - val_total_loss: 0.0362
# Epoch 2/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 607s 1s/step - class_loss: 0.0138 - regress_loss: 0.0515 - total_loss: 0.0583 - val_class_loss: 0.0011 - val_regress_loss: 0.0146 - val_total_loss: 0.0151
# Epoch 3/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 632s 1s/step - class_loss: 0.0121 - regress_loss: 0.0603 - total_loss: 0.0664 - val_class_loss: 0.0912 - val_regress_loss: 0.1501 - val_total_loss: 0.1957
# Epoch 4/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 2423s 5s/step - class_loss: 0.0148 - regress_loss: 0.0492 - total_loss: 0.0566 - val_class_loss: 0.2207 - val_regress_loss: 0.1678 - val_total_loss: 0.2781
# Epoch 5/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 562s 1s/step - class_loss: 0.0130 - regress_loss: 0.0449 - total_loss: 0.0515 - val_class_loss: 2.4401e-04 - val_regress_loss: 0.0449 - val_total_loss: 0.0450
# Epoch 6/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 542s 1s/step - class_loss: 0.0153 - regress_loss: 0.0500 - total_loss: 0.0577 - val_class_loss: 1.4011e-05 - val_regress_loss: 0.0042 - val_total_loss: 0.0042
# Epoch 7/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 526s 1s/step - class_loss: 0.0062 - regress_loss: 0.0170 - total_loss: 0.0201 - val_class_loss: 4.3525e-05 - val_regress_loss: 0.0018 - val_total_loss: 0.0018
# Epoch 8/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 533s 1s/step - class_loss: 0.0094 - regress_loss: 0.0349 - total_loss: 0.0396 - val_class_loss: 1.9219e-07 - val_regress_loss: 0.0399 - val_total_loss: 0.0399
# Epoch 9/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 539s 1s/step - class_loss: 0.0085 - regress_loss: 0.0345 - total_loss: 0.0387 - val_class_loss: 9.2693e-07 - val_regress_loss: 0.0260 - val_total_loss: 0.0260
# Epoch 10/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 540s 1s/step - class_loss: 0.0081 - regress_loss: 0.0213 - total_loss: 0.0253 - val_class_loss: 2.0401e-05 - val_regress_loss: 0.0049 - val_total_loss: 0.0050
# Epoch 11/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 533s 1s/step - class_loss: 0.0054 - regress_loss: 0.0127 - total_loss: 0.0154 - val_class_loss: 6.1376e-04 - val_regress_loss: 0.0157 - val_total_loss: 0.0160
# Epoch 12/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 532s 1s/step - class_loss: 0.0032 - regress_loss: 0.0105 - total_loss: 0.0121 - val_class_loss: 2.1840e-05 - val_regress_loss: 0.0083 - val_total_loss: 0.0084
# Epoch 13/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 529s 1s/step - class_loss: 0.0056 - regress_loss: 0.0108 - total_loss: 0.0136 - val_class_loss: 9.0251e-06 - val_regress_loss: 0.0102 - val_total_loss: 0.0102
# Epoch 14/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 530s 1s/step - class_loss: 0.0023 - regress_loss: 0.0136 - total_loss: 0.0147 - val_class_loss: 1.4442e-05 - val_regress_loss: 0.0051 - val_total_loss: 0.0051
# Epoch 15/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 555s 1s/step - class_loss: 0.0118 - regress_loss: 0.0358 - total_loss: 0.0417 - val_class_loss: 3.3894e-04 - val_regress_loss: 0.0178 - val_total_loss: 0.0180
# Epoch 16/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 6322s 13s/step - class_loss: 0.0072 - regress_loss: 0.0181 - total_loss: 0.0218 - val_class_loss: 0.0026 - val_regress_loss: 0.0122 - val_total_loss: 0.0136
# Epoch 17/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 579s 1s/step - class_loss: 0.0042 - regress_loss: 0.0125 - total_loss: 0.0146 - val_class_loss: 3.4765e-06 - val_regress_loss: 0.0152 - val_total_loss: 0.0152
# Epoch 18/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 538s 1s/step - class_loss: 0.0038 - regress_loss: 0.0100 - total_loss: 0.0119 - val_class_loss: 1.4459e-04 - val_regress_loss: 0.0104 - val_total_loss: 0.0105
# Epoch 19/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 595s 1s/step - class_loss: 0.0026 - regress_loss: 0.0082 - total_loss: 0.0095 - val_class_loss: 2.3069e-05 - val_regress_loss: 0.0034 - val_total_loss: 0.0034
# Epoch 20/20
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 556s 1s/step - class_loss: 0.0028 - regress_loss: 0.0081 - total_loss: 0.0095 - val_class_loss: 5.0277e-04 - val_regress_loss: 0.0131 - val_total_loss: 0.0134

# %%
hist.history
# Out:
# {'class_loss': [0.0008754045702517033,
#   0.0022884102072566748,
#   2.9701030143769458e-05,
#   0.000527362572029233,
#   0.003651931881904602,
#   5.5544169299537316e-05,
#   1.8771614122670144e-05,
#   3.2636708056088537e-06,
#   0.0028854962438344955,
#   0.00010155553900403902,
#   6.855633546365425e-05,
#   4.456912574823946e-05,
#   7.35311841708608e-05,
#   0.00117199937812984,
#   0.00015363460988737643,
#   0.00019709297339431942,
#   7.819789061613847e-06,
#   0.00014262201148085296,
#   4.186306341580348e-06,
#   6.133572242106311e-06],
#  'regress_loss': [0.012726273387670517,
#   0.008421367034316063,
#   0.004142993129789829,
#   0.019659465178847313,
#   0.03603311628103256,
#   0.0037346959579735994,
#   0.002099317731335759,
#   0.01388995349407196,
#   0.008626310154795647,
#   0.002630064729601145,
#   0.0015534884296357632,
#   0.003870696760714054,
#   0.003350178711116314,
#   0.013601647689938545,
#   0.007727981545031071,
#   0.001866089180111885,
#   0.0014508794993162155,
#   0.003103874623775482,
#   0.002677832031622529,
#   0.002807727549225092],
#  'total_loss': [0.013163975439965725,
#   0.009565572254359722,
#   0.00415784353390336,
#   0.019923146814107895,
#   0.03785908222198486,
#   0.003762467997148633,
#   0.002108703600242734,
#   0.013891585171222687,
#   0.010069058276712894,
#   0.0026808425318449736,
#   0.0015877665719017386,
#   0.0038929812144488096,
#   0.0033869442995637655,
#   0.0141876470297575,
#   0.007804798893630505,
#   0.00196463568136096,
#   0.001454789424315095,
#   0.003175185527652502,
#   0.0026799251791089773,
#   0.0028107943944633007],
#  'val_class_loss': [9.683244570624083e-05,
#   0.001087862765416503,
#   0.09115565568208694,
#   0.22069373726844788,
#   0.0002440107928123325,
#   1.4011211533215828e-05,
#   4.3524687498575076e-05,
#   1.9219238822643092e-07,
#   9.26934319522843e-07,
#   2.040122308244463e-05,
#   0.0006137600867077708,
#   2.1839838154846802e-05,
#   9.025074177770875e-06,
#   1.4442461178987287e-05,
#   0.00033893948420882225,
#   0.0026111039333045483,
#   3.4765364489430794e-06,
#   0.00014458931400440633,
#   2.306879650859628e-05,
#   0.0005027682054787874],
#  'val_regress_loss': [0.03610432520508766,
#   0.014580534771084785,
#   0.1501328945159912,
#   0.16777938604354858,
#   0.0449175164103508,
#   0.004219180904328823,
#   0.001769205555319786,
#   0.03989513963460922,
#   0.02596493810415268,
#   0.004949899390339851,
#   0.015704477205872536,
#   0.00834505446255207,
#   0.010170109570026398,
#   0.005092676728963852,
#   0.017806638032197952,
#   0.01224849745631218,
#   0.015177966095507145,
#   0.010386411100625992,
#   0.0033853426575660706,
#   0.013114392757415771],
#  'val_total_loss': [0.03615274280309677,
#   0.015124466270208359,
#   0.19571071863174438,
#   0.27812623977661133,
#   0.045039523392915726,
#   0.004226186312735081,
#   0.0017909678863361478,
#   0.03989523649215698,
#   0.025965401902794838,
#   0.004960100166499615,
#   0.016011357307434082,
#   0.008355974219739437,
#   0.01017462182790041,
#   0.005099897738546133,
#   0.017976107075810432,
#   0.013554049655795097,
#   0.015179703943431377,
#   0.010458705946803093,
#   0.0033968770876526833,
#   0.01336577720940113]}

# %%
fig, ax = plt.subplots(ncols=3, figsize=(20,5))

ax[0].plot(hist.history['total_loss'], color='teal', label='loss')
ax[0].plot(hist.history['val_total_loss'], color='orange', label='val loss')
ax[0].title.set_text('Loss')
ax[0].legend()

ax[1].plot(hist.history['class_loss'], color='teal', label='class loss')
ax[1].plot(hist.history['val_class_loss'], color='orange', label='val class loss')
ax[1].title.set_text('Classification Loss')
ax[1].legend()

ax[2].plot(hist.history['regress_loss'], color='teal', label='regress loss')
ax[2].plot(hist.history['val_regress_loss'], color='orange', label='val regress loss')
ax[2].title.set_text('Regression Loss')
ax[2].legend()

plt.show()

# %%
test_data = test.as_numpy_iterator()

# %%
test_sample = test_data.next()

# %%
yhat = facetracker.predict(test_sample[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4): 
    sample_image = test_sample[0][idx]
    sample_coords = yhat[1][idx]
    
    sample_image = sample_image.copy()

    if yhat[0][idx] > 0.9:
        cv2.rectangle(sample_image, 
                      tuple(np.multiply(sample_coords[:2], [120,120]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [120,120]).astype(int)), 
                            (255,0,0), 2)
    
    ax[idx].imshow(sample_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].

# %% [markdown]
# #### SAVE THE MODEL

# %%
from tensorflow.keras.models import load_model
import numpy as np

# %%
facetracker.save("FaceTracker20.keras")

# %%
facetracker = load_model("FaceTracker.keras")

# %%
facetracker
# Out:
# <Functional name=functional, built=True>

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    _ , frame = cap.read()
    frame = frame[50:500, 50:500,:]
    
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    resized = tf.image.resize(rgb, (120,120))
    
    yhat = facetracker.predict(np.expand_dims(resized/255,0))
    sample_coords = yhat[1][0]
    
    if yhat[0] > 0.5: 
        # Controls the main rectangle
        cv2.rectangle(frame, 
                      tuple(np.multiply(sample_coords[:2], [450,450]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [450,450]).astype(int)), 
                            (255,0,0), 2)
        # Controls the label rectangle
        cv2.rectangle(frame, 
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int), 
                                    [0,-30])),
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                    [80,0])), 
                            (255,0,0), -1)
        
        # Controls the text rendered
        cv2.putText(frame, 'face', tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                               [0,-5])),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    cv2.imshow('EyeTrack', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/st ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/ste ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
